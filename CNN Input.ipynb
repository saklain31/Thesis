# %%
import numpy as np
file = open("/home/saklain/dataset.txt", "r") 
t=0
mainlist=[]
mylist = []
k=-156.535598
cnt=0
for line in file:
    if(cnt==0):
        line=float(line.replace("\n",""))
        mylist.append(line)
    if(cnt==1):
        line=float(line.replace("\n",""))
        mylist.append(line)
    if(cnt==3):
        line=float(line.replace("\n",""))
        mylist.append(line)
    
    t=t+1
    cnt=cnt+1
    if cnt==7:
        cnt=0
    if(t%28==0):
        t=0
        a=np.asarray(mylist)
        mainlist.append(a)
        print(a)
        mylist.clear()
        #print("*******")
        
data=np.asarray(mainlist)
print(data)
print(data.size)
print(type(data))
# Out:
# [19.874883 21.29974   9.564905 20.022133 21.406734 10.753979 21.017741
#  22.128559 13.984289 23.314126 23.63173  15.85407 ]
# *******
# [17.833695 16.795047  7.215499 18.03136  17.085114  8.572404 18.913346
#  18.690837 12.374864 20.381798 21.088791 14.979619]
# *******
# [16.661207 17.751147  7.025976 16.959602 17.944302  8.420007 18.437594
#  19.050336 12.28013  20.147649 21.124692 14.838943]
# *******
# [18.160488 16.523818  6.799    18.371161 16.770531  8.25003  19.328706
#  18.217316 12.195588 20.741197 20.679348 14.840426]
# *******
# [17.668742 16.3522    5.760248 17.895195 16.669674  7.56618  18.889891
#  18.288731 11.952957 20.435773 20.753613 14.690051]
# *******
# [17.286777 16.850939  6.607325 17.546027 17.135671  8.060124 18.819486
#  18.61327  12.051896 20.488555 20.958951 14.794676]
# *******
# [15.665173 17.547828  9.837924 16.034969 17.793958 10.624169 18.100833
#  19.165879 13.039863 21.151042 21.184882 15.109966]
# *******
# ...

# %%
filenames = ['/home/saklain/door.txt', '/home/saklain/balcony.txt','/home/saklain/mid.txt','/home/saklain/un1.txt','/home/saklain/un2.txt','/home/saklain/un3.txt']
with open('/home/saklain/dataset.txt', 'w') as outfile:
    for fname in filenames:
        with open(fname) as infile:
            outfile.write(infile.read())

# %%
filenames = ['/home/saklain/doorTest.txt','/home/saklain/balconyTest.txt','/home/saklain/midTest.txt','/home/saklain/un1Test.txt','/home/saklain/un2Test.txt','/home/saklain/un3Test.txt']
with open('/home/saklain/testset.txt', 'w') as outfile:
    for fname in filenames:
        with open(fname) as infile:
            outfile.write(infile.read())

# %%
filenames = ['/home/saklain/csidata2/l1.txt','/home/saklain/csidata2/l2.txt','/home/saklain/csidata2/l3.txt']
with open('/home/saklain/csidata2/dataset.txt', 'w') as outfile:
    for fname in filenames:
        with open(fname) as infile:
            outfile.write(infile.read())

# %%
filenames = ['/home/saklain/csidata2/l1t.txt','/home/saklain/csidata2/l2t.txt','/home/saklain/csidata2/l3t.txt']
with open('/home/saklain/csidata2/testset.txt', 'w') as outfile:
    for fname in filenames:
        with open(fname) as infile:
            outfile.write(infile.read())

# %%
import numpy as np
temp = []
out = []

for i in range(1500):
    temp.append(1)
    tempfin=np.asarray(temp)
    out.append(tempfin)
    temp.clear()
    
for i in range(1500):
    temp.append(2)
    tempfin=np.asarray(temp)
    out.append(tempfin)
    temp.clear()
    
for i in range(1500):
    temp.append(3)
    tempfin=np.asarray(temp)
    out.append(tempfin)
    temp.clear()
for i in range(1500):
    temp.append(4)
    tempfin=np.asarray(temp)
    out.append(tempfin)
    temp.clear()
for i in range(1500):
    temp.append(5)
    tempfin=np.asarray(temp)
    out.append(tempfin)
    temp.clear()
    
for i in range(1500):
    temp.append(6)
    tempfin=np.asarray(temp)
    out.append(tempfin)
    temp.clear()
outf=np.asarray(out)
print(outf)
print(outf.size)
print(type(outf))
# Out:
# [[1]
#  [1]
#  [1]
#  ...
#  [6]
#  [6]
#  [6]]
# 9000
# <class 'numpy.ndarray'>

# %%
filenames = ['/home/saklain/right.txt','/home/saklain/left.txt']
with open('/home/saklain/direction.txt', 'w') as outfile:
    for fname in filenames:
        with open(fname) as infile:
            outfile.write(infile.read())
